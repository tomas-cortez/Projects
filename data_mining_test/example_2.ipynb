# %%
#Importe de librerías
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_users = 'https://jsonplaceholder.typicode.com/users'
url_albums = 'https://jsonplaceholder.typicode.com/albums'

# Solicita descargar el contenido de las url
response_users= requests.request("GET",url_users)
response_albums= requests.request("GET",url_albums)
                                 

soup_users= BeautifulSoup(response_users.text, 'html.parser')
soup_albums=BeautifulSoup(response_albums.text, 'html.parser')
print (soup_albums)
# Out:
# [
#   {
#     "userId": 1,
#     "id": 1,
#     "title": "quidem molestiae enim"
#   },
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "sunt qui excepturi placeat culpa"
#   },
#   {
#     "userId": 1,
#     "id": 3,
#     "title": "omnis laborum odio"
#   },
#   {
#     "userId": 1,
#     "id": 4,
#     "title": "non esse culpa molestiae omnis sed optio"
#   },
#   {
#     "userId": 1,
#     "id": 5,
#     "title": "eaque aut omnis a"
#   },
#   {
#     "userId": 1,
#     "id": 6,
#     "title": "natus impedit quibusdam illo est"
#   },
#   {
#     "userId": 1,
#     "id": 7,
#     "title": "quibusdam autem aliquid et et quia"
#   },
#   {
#     "userId": 1,
#     "id": 8,
#     "title": "qui fuga est a eum"
#   },
#   {
#     "userId": 1,
#     "id": 9,
#     "title": "saepe unde necessitatibus rem"
#   },
#   {
#     "userId": 1,
#     "id": 10,
#     "title": "distinctio laborum qui"
#   },
#   {
#     "userId": 2,
#     "id": 11,
# ...

# %%
dicc_albums=json.loads(soup_albums.text)
for reg in dicc_albums:
    print('ID_album: {} - Titulo_album: {} '.format(reg['id'], reg['title']))
# Out:
# ID_album: 1 - Titulo_album: quidem molestiae enim
# ID_album: 2 - Titulo_album: sunt qui excepturi placeat culpa
# ID_album: 3 - Titulo_album: omnis laborum odio
# ID_album: 4 - Titulo_album: non esse culpa molestiae omnis sed optio
# ID_album: 5 - Titulo_album: eaque aut omnis a
# ID_album: 6 - Titulo_album: natus impedit quibusdam illo est
# ID_album: 7 - Titulo_album: quibusdam autem aliquid et et quia
# ID_album: 8 - Titulo_album: qui fuga est a eum
# ID_album: 9 - Titulo_album: saepe unde necessitatibus rem
# ID_album: 10 - Titulo_album: distinctio laborum qui
# ID_album: 11 - Titulo_album: quam nostrum impedit mollitia quod et dolor
# ID_album: 12 - Titulo_album: consequatur autem doloribus natus consectetur
# ID_album: 13 - Titulo_album: ab rerum non rerum consequatur ut ea unde
# ID_album: 14 - Titulo_album: ducimus molestias eos animi atque nihil
# ID_album: 15 - Titulo_album: ut pariatur rerum ipsum natus repellendus praesentium
# ...

# %%
for x in dicc_albums:
    a=x.get('userId')
    info_album= ('ID_album: {} - Titulo_album: {} '.format(reg['id'], reg['title'])
    for z in dicc_users:
        b=z.get('id')
        if a==b:
            print(x,z)
# Out:
# {'userId': 1, 'id': 1, 'title': 'quidem molestiae enim'} {'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}
# {'userId': 1, 'id': 2, 'title': 'sunt qui excepturi placeat culpa'} {'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}
# ...

# %%
#info_user=('ID_user: {} - Nombre_album: {} - Nombre_city'.format(reg['id'], reg['name'],reg['address']['city']))
info_album= ('ID_album: {} - Titulo_album: {} '.format(reg['id'], reg['title'])
